# %%
import importlib
import intake
import numpy as np
import xarray as xr

from cmip6_to_xarray import get_cmip6_catalogue

# %%
# Get full catalogue of CMIP6 data on glade or cloud
cmip6_collection = get_cmip6_catalogue()

# %%
# See overview of CMIP6 catalogue
import pprint 
uni_dict = cmip6_collection.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 99,
#                    'values': ['piClim-CH4', 'piClim-NTCF', 'piClim-control',
#                               'ssp370', 'piClim-2xDMS', 'piClim-2xdust',
#                               'piClim-2xfire', 'piClim-2xss', 'piClim-BC',
#                               'piClim-HC', 'piClim-N2O', 'piClim-OC',
#                               'piClim-SO2', '1pctCO2-bgc', 'esm-ssp585',
#                               'hist-bgc', 'amip-4xCO2', 'amip-future4K',
#                               'amip-m4K', 'amip-p4K', 'amip', 'abrupt-2xCO2',
#                               'abrupt-solp4p', 'abrupt-0p5xCO2', 'amip-lwoff',
#                               'amip-p4K-lwoff', 'abrupt-solm4p', 'aqua-4xCO2',
#                               'aqua-control-lwoff', 'aqua-control',
#                               'aqua-p4K-lwoff', 'aqua-p4K', '1pctCO2',
#                               'abrupt-4xCO2', 'historical', 'piControl',
#                               'esm-hist', 'esm-piControl', 'ssp126', 'ssp245',
#                               'ssp585', 'esm-piControl-spinup',
#                               'piControl-spinup', 'hist-GHG', 'hist-aer',
#                               'hist-nat', 'hist-CO2', 'hist-sol',
#                               'hist-stratO3', 'hist-volc', 'ssp245-GHG',
#                               'ssp245-aer', 'ssp245-nat', 'ssp245-stratO3',
#                               'dcppA-assim', 'dcppA-hindcast',
#                               'dcppC-hindcast-noAgung',
#                               'dcppC-hindcast-noElChichon',
#                               'dcppC-hindcast-noPinatubo', 'dcppC-amv-neg',
#                               'dcppC-amv-pos', 'dcppC-amv-ExTrop-neg',
#                               'dcppC-amv-ExTrop-pos', 'dcppC-amv-Trop-neg',
#                               'dcppC-amv-Trop-pos', 'dcppC-atl-control',
#                               'dcppC-atl-pacemaker', 'dcppC-ipv-NexTrop-neg',
#                               'dcppC-ipv-NexTrop-pos', 'dcppC-ipv-neg',
#                               'dcppC-ipv-pos', 'dcppC-pac-control',
#                               'dcppC-pac-pacemaker', 'faf-heat',
#                               'faf-passiveheat', 'faf-stress', 'faf-water',
#                               'faf-all', 'highresSST-present', 'hist-1950',
#                               'control-1950', 'land-hist', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'hist-noLu', 'land-noLu',
#                               'omip1', 'lig127k', 'midHolocene', 'lgm',
#                               'piClim-4xCO2', 'piClim-aer', 'piClim-anthro',
#                               'piClim-ghg', 'piClim-lu', 'ssp119', 'ssp434',
#                               'ssp460', 'ssp534-over']},
#  'source_id': {'count': 51,
#                'values': ['BCC-ESM1', 'CNRM-ESM2-1', 'MIROC6', 'UKESM1-0-LL',
#                           'MRI-ESM2-0', 'CESM2-WACCM', 'BCC-CSM2-MR', 'CanESM5',
#                           'GISS-E2-1-G', 'CESM2', 'GFDL-ESM4', 'CNRM-CM6-1',
#                           'IPSL-CM6A-LR', 'GISS-E2-1-H', 'GFDL-CM4',
#                           'AWI-CM-1-1-MR', 'CAMS-CSM1-0', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'CNRM-CM6-1-HR', 'E3SM-1-0', 'E3SM-1-1',
#                           'EC-Earth3-LR', 'EC-Earth3-Veg', 'EC-Earth3',
#                           'FIO-ESM-2-0', 'MIROC-ES2L', 'HadGEM3-GC31-LL',
#                           'HadGEM3-GC31-MM', 'MPI-ESM1-2-HR', 'GISS-E2-1-G-CC',
#                           'NorCPM1', 'NorESM1-F', 'NorESM2-LM', 'NESM3',
#                           'SAM0-UNICON', 'MCM-UA-1-0', 'CESM1-1-CAM5-CMIP5',
#                           'CMCC-CM2-HR4', 'CMCC-CM2-VHR4', 'ECMWF-IFS-HR',
#                           'ECMWF-IFS-LR', 'IPSL-CM6A-ATM-HR', 'NICAM16-7S',
#                           'NICAM16-8S', 'NICAM16-9S', 'HadGEM3-GC31-HM',
#                           'HadGEM3-GC31-LM', 'MRI-AGCM3-2-H', 'MRI-AGCM3-2-S',
#                           'GFDL-CM4C192']},
#  'table_id': {'count': 28,
#               'values': ['Amon', 'day', 'AERmon', 'AERmonZ', 'CFmon', 'fx',
#                          'Lmon', 'Oyr', 'Omon', 'LImon', 'Ofx', 'SImon', '3hr',
#                          '6hrLev', 'Oday', 'Aclim', 'Emon', 'CFday', '6hrPlev',
#                          'CF3hr', 'Oclim', 'SIclim', 'Eclim', 'Odec', 'IfxGre',
#                          'ImonGre', '6hrPlevPt', 'E3hr']}}

# %%
# Search for specific combination of conditions within catalogue
cat = cmip6_collection.search(experiment_id=['piControl'],
                              table_id='SImon', variable_id='siconc', grid_label='gn')
cat.df
# Out:
#    activity_id       institution_id        source_id experiment_id member_id  \
# 0         CMIP                 CAMS      CAMS-CSM1-0     piControl  r1i1p1f1
# 1         CMIP                CCCma          CanESM5     piControl  r1i1p1f1
# 2         CMIP                CCCma          CanESM5     piControl  r1i1p2f1
# 3         CMIP         CNRM-CERFACS      CNRM-ESM2-1     piControl  r1i1p1f2
# 4         CMIP  EC-Earth-Consortium    EC-Earth3-Veg     piControl  r1i1p1f1
# 5         CMIP  EC-Earth-Consortium        EC-Earth3     piControl  r1i1p1f1
# 6         CMIP             FIO-QLNM      FIO-ESM-2-0     piControl  r1i1p1f1
# 7         CMIP                 IPSL     IPSL-CM6A-LR     piControl  r1i2p1f1
# 8         CMIP                MIROC       MIROC-ES2L     piControl  r1i1p1f2
# 9         CMIP                MIROC           MIROC6     piControl  r1i1p1f1
# 10        CMIP                 MOHC  HadGEM3-GC31-LL     piControl  r1i1p1f1
# 11        CMIP                 MOHC      UKESM1-0-LL     piControl  r1i1p1f2
# 12        CMIP                  MRI       MRI-ESM2-0     piControl  r1i1p1f1
# 13        CMIP                 NCAR      CESM2-WACCM     piControl  r1i1p1f1
# 14        CMIP                 NCAR            CESM2     piControl  r1i1p1f1
# 15        CMIP                  NCC        NorESM1-F     piControl  r1i1p1f1
# 16        CMIP            NOAA-GFDL         GFDL-CM4     piControl  r1i1p1f1
# 17        CMIP            NOAA-GFDL        GFDL-ESM4     piControl  r1i1p1f1
# 18        CMIP                NUIST            NESM3     piControl  r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0     SImon      siconc         gn
# 1     SImon      siconc         gn
# 2     SImon      siconc         gn
# 3     SImon      siconc         gn
# 4     SImon      siconc         gn
# 5     SImon      siconc         gn
# 6     SImon      siconc         gn
# 7     SImon      siconc         gn
# 8     SImon      siconc         gn
# 9     SImon      siconc         gn
# 10    SImon      siconc         gn
# 11    SImon      siconc         gn
# 12    SImon      siconc         gn
# 13    SImon      siconc         gn
# 14    SImon      siconc         gn
# 15    SImon      siconc         gn
# 16    SImon      siconc         gn
# 17    SImon      siconc         gn
# 18    SImon      siconc         gn
#
#                                                zstore  dcpp_init_year
# 0   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/piControl/r1i...             NaN
# 1   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p1...             NaN
# 2   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p2...             NaN
# 3   gs://cmip6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/piCon...             NaN
# 4   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3-...             NaN
# 5   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3/...             NaN
# 6   gs://cmip6/CMIP/FIO-QLNM/FIO-ESM-2-0/piControl...             NaN
# 7   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/piControl/r1...             NaN
# 8   gs://cmip6/CMIP/MIROC/MIROC-ES2L/piControl/r1i...             NaN
# 9   gs://cmip6/CMIP/MIROC/MIROC6/piControl/r1i1p1f...             NaN
# 10  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/piControl...             NaN
# 11  gs://cmip6/CMIP/MOHC/UKESM1-0-LL/piControl/r1i...             NaN
# 12  gs://cmip6/CMIP/MRI/MRI-ESM2-0/piControl/r1i1p...             NaN
# 13  gs://cmip6/CMIP/NCAR/CESM2-WACCM/piControl/r1i...             NaN
# 14  gs://cmip6/CMIP/NCAR/CESM2/piControl/r1i1p1f1/...             NaN
# 15  gs://cmip6/CMIP/NCC/NorESM1-F/piControl/r1i1p1...             NaN
# 16  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/piControl/r...             NaN
# 17  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/piControl/...             NaN
# 18  gs://cmip6/CMIP/NUIST/NESM3/piControl/r1i1p1f1...             NaN

# %%
cat = cmip6_collection.search(experiment_id=['piControl'],
                              table_id='Amon', variable_id='tas', grid_label='gn')
cat.df
# Out:
#    activity_id institution_id        source_id experiment_id   member_id  \
# 0         CMIP            BCC      BCC-CSM2-MR     piControl    r1i1p1f1
# 1         CMIP            BCC         BCC-ESM1     piControl    r1i1p1f1
# 2         CMIP           CAMS      CAMS-CSM1-0     piControl    r1i1p1f1
# 3         CMIP          CCCma          CanESM5     piControl    r1i1p1f1
# 4         CMIP          CCCma          CanESM5     piControl    r1i1p2f1
# 5         CMIP       FIO-QLNM      FIO-ESM-2-0     piControl    r1i1p1f1
# 6         CMIP          MIROC       MIROC-ES2L     piControl    r1i1p1f2
# 7         CMIP          MIROC           MIROC6     piControl    r1i1p1f1
# 8         CMIP           MOHC  HadGEM3-GC31-LL     piControl    r1i1p1f1
# 9         CMIP           MOHC  HadGEM3-GC31-MM     piControl    r1i1p1f1
# 10        CMIP           MOHC      UKESM1-0-LL     piControl    r1i1p1f2
# 11        CMIP            MRI       MRI-ESM2-0     piControl    r1i1p1f1
# 12        CMIP      NASA-GISS   GISS-E2-1-G-CC     piControl    r1i1p1f1
# 13        CMIP      NASA-GISS      GISS-E2-1-G     piControl  r101i1p1f1
# 14        CMIP      NASA-GISS      GISS-E2-1-G     piControl  r102i1p1f1
# 15        CMIP      NASA-GISS      GISS-E2-1-G     piControl    r1i1p1f1
# 16        CMIP      NASA-GISS      GISS-E2-1-G     piControl    r1i1p1f2
# 17        CMIP      NASA-GISS      GISS-E2-1-G     piControl    r1i1p1f3
# 18        CMIP      NASA-GISS      GISS-E2-1-G     piControl    r2i1p1f1
# 19        CMIP      NASA-GISS      GISS-E2-1-H     piControl    r1i1p1f1
# 20        CMIP           NCAR      CESM2-WACCM     piControl    r1i1p1f1
# 21        CMIP           NCAR            CESM2     piControl    r1i1p1f1
# 22        CMIP            NCC        NorESM1-F     piControl    r1i1p1f1
# 23        CMIP          NUIST            NESM3     piControl    r1i1p1f1
# 24        CMIP            SNU      SAM0-UNICON     piControl    r1i1p1f1
# 25        CMIP             UA       MCM-UA-1-0     piControl    r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0      Amon         tas         gn
# 1      Amon         tas         gn
# 2      Amon         tas         gn
# 3      Amon         tas         gn
# 4      Amon         tas         gn
# 5      Amon         tas         gn
# 6      Amon         tas         gn
# 7      Amon         tas         gn
# 8      Amon         tas         gn
# 9      Amon         tas         gn
# 10     Amon         tas         gn
# 11     Amon         tas         gn
# 12     Amon         tas         gn
# 13     Amon         tas         gn
# 14     Amon         tas         gn
# 15     Amon         tas         gn
# 16     Amon         tas         gn
# 17     Amon         tas         gn
# 18     Amon         tas         gn
# 19     Amon         tas         gn
# 20     Amon         tas         gn
# 21     Amon         tas         gn
# 22     Amon         tas         gn
# 23     Amon         tas         gn
# 24     Amon         tas         gn
# 25     Amon         tas         gn
#
#                                                zstore  dcpp_init_year
# 0   gs://cmip6/CMIP/BCC/BCC-CSM2-MR/piControl/r1i1...             NaN
# 1   gs://cmip6/CMIP/BCC/BCC-ESM1/piControl/r1i1p1f...             NaN
# 2   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/piControl/r1i...             NaN
# 3   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p1...             NaN
# 4   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p2...             NaN
# 5   gs://cmip6/CMIP/FIO-QLNM/FIO-ESM-2-0/piControl...             NaN
# 6   gs://cmip6/CMIP/MIROC/MIROC-ES2L/piControl/r1i...             NaN
# 7   gs://cmip6/CMIP/MIROC/MIROC6/piControl/r1i1p1f...             NaN
# 8   gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/piControl...             NaN
# 9   gs://cmip6/CMIP/MOHC/HadGEM3-GC31-MM/piControl...             NaN
# 10  gs://cmip6/CMIP/MOHC/UKESM1-0-LL/piControl/r1i...             NaN
# 11  gs://cmip6/CMIP/MRI/MRI-ESM2-0/piControl/r1i1p...             NaN
# 12  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G-CC/piCon...             NaN
# 13  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 14  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 15  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 16  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 17  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 18  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 19  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-H/piContro...             NaN
# 20  gs://cmip6/CMIP/NCAR/CESM2-WACCM/piControl/r1i...             NaN
# 21  gs://cmip6/CMIP/NCAR/CESM2/piControl/r1i1p1f1/...             NaN
# 22  gs://cmip6/CMIP/NCC/NorESM1-F/piControl/r1i1p1...             NaN
# 23  gs://cmip6/CMIP/NUIST/NESM3/piControl/r1i1p1f1...             NaN
# 24  gs://cmip6/CMIP/SNU/SAM0-UNICON/piControl/r1i1...             NaN
# 25  gs://cmip6/CMIP/UA/MCM-UA-1-0/piControl/r1i1p1...             NaN
