# %%
import importlib
import intake
import numpy as np
import xarray as xr

from explore_utils import get_cmip6_catalogue

# %%
# Get full catalogue of CMIP6 data on glade or cloud
cmip6_collection = get_cmip6_catalogue()

# %%
# See overview of CMIP6 catalogue
import pprint 
uni_dict = cmip6_collection.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 101,
#                    'values': ['histSST', 'piClim-CH4', 'piClim-NTCF',
#                               'piClim-control', 'ssp370', 'piClim-2xDMS',
#                               'piClim-2xdust', 'piClim-2xfire', 'piClim-2xss',
#                               'piClim-BC', 'piClim-HC', 'piClim-N2O',
#                               'piClim-OC', 'piClim-SO2', 'piClim-aer',
#                               '1pctCO2-bgc', 'esm-ssp585', 'hist-bgc',
#                               'amip-4xCO2', 'amip-future4K', 'amip-m4K',
#                               'amip-p4K', 'amip', 'abrupt-2xCO2',
#                               'abrupt-solp4p', 'abrupt-0p5xCO2', 'amip-lwoff',
#                               'amip-p4K-lwoff', 'abrupt-solm4p', 'aqua-4xCO2',
#                               'aqua-control-lwoff', 'aqua-control',
#                               'aqua-p4K-lwoff', 'aqua-p4K', 'historical',
#                               'piControl', '1pctCO2', 'abrupt-4xCO2',
#                               'esm-hist', 'esm-piControl', 'ssp126', 'ssp245',
#                               'ssp585', 'esm-piControl-spinup',
#                               'piControl-spinup', 'hist-GHG', 'hist-aer',
#                               'hist-nat', 'hist-CO2', 'hist-sol',
#                               'hist-stratO3', 'hist-volc', 'ssp245-GHG',
#                               'ssp245-aer', 'ssp245-nat', 'ssp245-stratO3',
#                               'dcppA-hindcast', 'dcppA-assim',
#                               'dcppC-hindcast-noAgung',
#                               'dcppC-hindcast-noElChichon',
#                               'dcppC-hindcast-noPinatubo', 'dcppC-amv-neg',
#                               'dcppC-amv-pos', 'dcppC-amv-ExTrop-neg',
#                               'dcppC-amv-ExTrop-pos', 'dcppC-amv-Trop-neg',
#                               'dcppC-amv-Trop-pos', 'dcppC-atl-control',
#                               'dcppC-atl-pacemaker', 'dcppC-ipv-NexTrop-neg',
#                               'dcppC-ipv-NexTrop-pos', 'dcppC-ipv-neg',
#                               'dcppC-ipv-pos', 'dcppC-pac-control',
#                               'dcppC-pac-pacemaker', 'faf-heat',
#                               'faf-passiveheat', 'faf-stress', 'faf-water',
#                               'faf-all', 'amip-hist', 'highresSST-present',
#                               'hist-1950', 'control-1950', 'land-hist',
#                               'deforest-globe', 'esm-ssp585-ssp126Lu',
#                               'hist-noLu', 'land-noLu', 'omip1', 'lig127k',
#                               'midHolocene', 'lgm', 'piClim-4xCO2',
#                               'piClim-anthro', 'piClim-ghg', 'piClim-lu',
#                               'ssp119', 'ssp434', 'ssp460', 'ssp534-over']},
#  'source_id': {'count': 70,
#                'values': ['BCC-ESM1', 'CNRM-ESM2-1', 'MIROC6', 'UKESM1-0-LL',
#                           'MRI-ESM2-0', 'CESM2-WACCM', 'NorESM2-LM',
#                           'GFDL-ESM4', 'BCC-CSM2-MR', 'CanESM5',
#                           'ACCESS-ESM1-5', 'E3SM-1-1-ECA', 'E3SM-1-1',
#                           'IPSL-CM6A-LR', 'MIROC-ES2L', 'GISS-E2-1-G', 'CESM2',
#                           'CNRM-CM6-1', 'GISS-E2-1-H', 'GFDL-CM4', 'TaiESM1',
#                           'AWI-CM-1-1-MR', 'CAMS-CSM1-0', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'CanESM5-CanOE', 'IITM-ESM',
#                           'CNRM-CM6-1-HR', 'ACCESS-CM2', 'E3SM-1-0',
#                           'EC-Earth3-LR', 'EC-Earth3-Veg', 'EC-Earth3',
#                           'FIO-ESM-2-0', 'MPI-ESM-1-2-HAM', 'INM-CM4-8',
#                           'INM-CM5-0', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM',
#                           'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'GISS-E2-1-G-CC',
#                           'GISS-E2-2-G', 'CESM2-FV2', 'CESM2-WACCM-FV2',
#                           'NorCPM1', 'NorESM1-F', 'NorESM2-MM', 'KACE-1-0-G',
#                           'GFDL-AM4', 'NESM3', 'SAM0-UNICON', 'CIESM',
#                           'MCM-UA-1-0', 'CESM1-1-CAM5-CMIP5', 'CMCC-CM2-HR4',
#                           'CMCC-CM2-VHR4', 'ECMWF-IFS-HR', 'ECMWF-IFS-LR',
#                           'IPSL-CM6A-ATM-HR', 'NICAM16-7S', 'NICAM16-8S',
#                           'NICAM16-9S', 'HadGEM3-GC31-HM', 'HadGEM3-GC31-LM',
#                           'MPI-ESM1-2-XR', 'MRI-AGCM3-2-H', 'MRI-AGCM3-2-S',
#                           'GFDL-CM4C192', 'GFDL-OM4p5B']},
#  'table_id': {'count': 29,
#               'values': ['AERmon', 'Amon', 'LImon', 'Lmon', 'Omon', 'day',
#                          'AERmonZ', 'CFmon', 'fx', 'SImon', 'Oyr', 'Ofx', '3hr',
#                          '6hrLev', 'Oday', 'Aclim', 'Emon', 'CFday', '6hrPlev',
#                          'CF3hr', 'Oclim', 'SIclim', 'Eclim', 'Odec', 'AERhr',
#                          'IfxGre', 'ImonGre', '6hrPlevPt', 'E3hr']}}

# %%
# Search for specific combination of conditions within catalogue
cat = cmip6_collection.search(experiment_id=['piControl'],
                              table_id='SImon', variable_id='siconc', grid_label='gn')
cat.df
# Out:
#    activity_id       institution_id        source_id experiment_id member_id  \
# 0         CMIP                 CAMS      CAMS-CSM1-0     piControl  r1i1p1f1
# 1         CMIP                CCCma          CanESM5     piControl  r1i1p1f1
# 2         CMIP                CCCma          CanESM5     piControl  r1i1p2f1
# 3         CMIP         CNRM-CERFACS      CNRM-ESM2-1     piControl  r1i1p1f2
# 4         CMIP         CSIRO-ARCCSS       ACCESS-CM2     piControl  r1i1p1f1
# 5         CMIP                CSIRO    ACCESS-ESM1-5     piControl  r1i1p1f1
# 6         CMIP  EC-Earth-Consortium    EC-Earth3-Veg     piControl  r1i1p1f1
# 7         CMIP  EC-Earth-Consortium        EC-Earth3     piControl  r1i1p1f1
# 8         CMIP             FIO-QLNM      FIO-ESM-2-0     piControl  r1i1p1f1
# 9         CMIP    HAMMOZ-Consortium  MPI-ESM-1-2-HAM     piControl  r1i1p1f1
# 10        CMIP                 IPSL     IPSL-CM6A-LR     piControl  r1i1p1f1
# 11        CMIP                 IPSL     IPSL-CM6A-LR     piControl  r1i2p1f1
# 12        CMIP                MIROC       MIROC-ES2L     piControl  r1i1p1f2
# 13        CMIP                MIROC           MIROC6     piControl  r1i1p1f1
# 14        CMIP                 MOHC  HadGEM3-GC31-LL     piControl  r1i1p1f1
# 15        CMIP                MPI-M    MPI-ESM1-2-HR     piControl  r1i1p1f1
# 16        CMIP                MPI-M    MPI-ESM1-2-LR     piControl  r1i1p1f1
# 17        CMIP                  MRI       MRI-ESM2-0     piControl  r1i1p1f1
# 18        CMIP                 NCAR        CESM2-FV2     piControl  r1i1p1f1
# 19        CMIP                 NCAR  CESM2-WACCM-FV2     piControl  r1i1p1f1
# 20        CMIP                 NCAR      CESM2-WACCM     piControl  r1i1p1f1
# 21        CMIP                 NCAR            CESM2     piControl  r1i1p1f1
# 22        CMIP                  NCC          NorCPM1     piControl  r1i1p1f1
# 23        CMIP                  NCC          NorCPM1     piControl  r2i1p1f1
# 24        CMIP                  NCC          NorCPM1     piControl  r3i1p1f1
# 25        CMIP                  NCC        NorESM1-F     piControl  r1i1p1f1
# 26        CMIP                  NCC       NorESM2-LM     piControl  r1i1p1f1
# 27        CMIP            NOAA-GFDL         GFDL-CM4     piControl  r1i1p1f1
# 28        CMIP            NOAA-GFDL        GFDL-ESM4     piControl  r1i1p1f1
# 29        CMIP                NUIST            NESM3     piControl  r1i1p1f1
# 30        CMIP                  SNU      SAM0-UNICON     piControl  r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0     SImon      siconc         gn
# 1     SImon      siconc         gn
# 2     SImon      siconc         gn
# 3     SImon      siconc         gn
# 4     SImon      siconc         gn
# 5     SImon      siconc         gn
# 6     SImon      siconc         gn
# 7     SImon      siconc         gn
# 8     SImon      siconc         gn
# 9     SImon      siconc         gn
# 10    SImon      siconc         gn
# 11    SImon      siconc         gn
# 12    SImon      siconc         gn
# 13    SImon      siconc         gn
# 14    SImon      siconc         gn
# 15    SImon      siconc         gn
# 16    SImon      siconc         gn
# 17    SImon      siconc         gn
# 18    SImon      siconc         gn
# 19    SImon      siconc         gn
# 20    SImon      siconc         gn
# 21    SImon      siconc         gn
# 22    SImon      siconc         gn
# 23    SImon      siconc         gn
# 24    SImon      siconc         gn
# 25    SImon      siconc         gn
# 26    SImon      siconc         gn
# 27    SImon      siconc         gn
# 28    SImon      siconc         gn
# 29    SImon      siconc         gn
# 30    SImon      siconc         gn
#
#                                                zstore  dcpp_init_year
# 0   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/piControl/r1i...             NaN
# 1   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p1...             NaN
# 2   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p2...             NaN
# 3   gs://cmip6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/piCon...             NaN
# 4   gs://cmip6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/piCont...             NaN
# 5   gs://cmip6/CMIP/CSIRO/ACCESS-ESM1-5/piControl/...             NaN
# 6   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3-...             NaN
# 7   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3/...             NaN
# 8   gs://cmip6/CMIP/FIO-QLNM/FIO-ESM-2-0/piControl...             NaN
# 9   gs://cmip6/CMIP/HAMMOZ-Consortium/MPI-ESM-1-2-...             NaN
# 10  gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/piControl/r1...             NaN
# 11  gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/piControl/r1...             NaN
# 12  gs://cmip6/CMIP/MIROC/MIROC-ES2L/piControl/r1i...             NaN
# 13  gs://cmip6/CMIP/MIROC/MIROC6/piControl/r1i1p1f...             NaN
# 14  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/piControl...             NaN
# 15  gs://cmip6/CMIP/MPI-M/MPI-ESM1-2-HR/piControl/...             NaN
# 16  gs://cmip6/CMIP/MPI-M/MPI-ESM1-2-LR/piControl/...             NaN
# 17  gs://cmip6/CMIP/MRI/MRI-ESM2-0/piControl/r1i1p...             NaN
# 18  gs://cmip6/CMIP/NCAR/CESM2-FV2/piControl/r1i1p...             NaN
# 19  gs://cmip6/CMIP/NCAR/CESM2-WACCM-FV2/piControl...             NaN
# 20  gs://cmip6/CMIP/NCAR/CESM2-WACCM/piControl/r1i...             NaN
# 21  gs://cmip6/CMIP/NCAR/CESM2/piControl/r1i1p1f1/...             NaN
# 22  gs://cmip6/CMIP/NCC/NorCPM1/piControl/r1i1p1f1...             NaN
# 23  gs://cmip6/CMIP/NCC/NorCPM1/piControl/r2i1p1f1...             NaN
# 24  gs://cmip6/CMIP/NCC/NorCPM1/piControl/r3i1p1f1...             NaN
# 25  gs://cmip6/CMIP/NCC/NorESM1-F/piControl/r1i1p1...             NaN
# 26  gs://cmip6/CMIP/NCC/NorESM2-LM/piControl/r1i1p...             NaN
# 27  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/piControl/r...             NaN
# 28  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/piControl/...             NaN
# 29  gs://cmip6/CMIP/NUIST/NESM3/piControl/r1i1p1f1...             NaN
# 30  gs://cmip6/CMIP/SNU/SAM0-UNICON/piControl/r1i1...             NaN

# %%
cat = cmip6_collection.search(experiment_id=['piControl'],
                              table_id='Amon', variable_id='tas', grid_label='gn')
cat.df
# Out:
#    activity_id     institution_id        source_id experiment_id   member_id  \
# 0         CMIP            AS-RCEC          TaiESM1     piControl    r1i1p1f1
# 1         CMIP                BCC      BCC-CSM2-MR     piControl    r1i1p1f1
# 2         CMIP                BCC         BCC-ESM1     piControl    r1i1p1f1
# 3         CMIP               CAMS      CAMS-CSM1-0     piControl    r1i1p1f1
# 4         CMIP                CAS        FGOALS-g3     piControl    r1i1p1f1
# 5         CMIP              CCCma          CanESM5     piControl    r1i1p1f1
# 6         CMIP              CCCma          CanESM5     piControl    r1i1p2f1
# 7         CMIP          CCCR-IITM         IITM-ESM     piControl    r1i1p1f1
# 8         CMIP       CSIRO-ARCCSS       ACCESS-CM2     piControl    r1i1p1f1
# 9         CMIP              CSIRO    ACCESS-ESM1-5     piControl    r1i1p1f1
# 10        CMIP           FIO-QLNM      FIO-ESM-2-0     piControl    r1i1p1f1
# 11        CMIP  HAMMOZ-Consortium  MPI-ESM-1-2-HAM     piControl    r1i1p1f1
# 12        CMIP              MIROC       MIROC-ES2L     piControl    r1i1p1f2
# 13        CMIP              MIROC           MIROC6     piControl    r1i1p1f1
# 14        CMIP               MOHC  HadGEM3-GC31-LL     piControl    r1i1p1f1
# 15        CMIP               MOHC  HadGEM3-GC31-MM     piControl    r1i1p1f1
# 16        CMIP               MOHC      UKESM1-0-LL     piControl    r1i1p1f2
# 17        CMIP              MPI-M    MPI-ESM1-2-HR     piControl    r1i1p1f1
# 18        CMIP              MPI-M    MPI-ESM1-2-LR     piControl    r1i1p1f1
# 19        CMIP                MRI       MRI-ESM2-0     piControl    r1i1p1f1
# 20        CMIP                MRI       MRI-ESM2-0     piControl    r1i2p1f1
# 21        CMIP          NASA-GISS   GISS-E2-1-G-CC     piControl    r1i1p1f1
# 22        CMIP          NASA-GISS      GISS-E2-1-G     piControl  r101i1p1f1
# 23        CMIP          NASA-GISS      GISS-E2-1-G     piControl  r102i1p1f1
# 24        CMIP          NASA-GISS      GISS-E2-1-G     piControl    r1i1p1f1
# 25        CMIP          NASA-GISS      GISS-E2-1-G     piControl    r1i1p1f2
# 26        CMIP          NASA-GISS      GISS-E2-1-G     piControl    r1i1p1f3
# 27        CMIP          NASA-GISS      GISS-E2-1-G     piControl    r1i1p3f1
# 28        CMIP          NASA-GISS      GISS-E2-1-G     piControl    r2i1p1f1
# 29        CMIP          NASA-GISS      GISS-E2-1-H     piControl    r1i1p1f1
# 30        CMIP          NASA-GISS      GISS-E2-2-G     piControl    r1i1p1f1
# 31        CMIP               NCAR        CESM2-FV2     piControl    r1i1p1f1
# 32        CMIP               NCAR  CESM2-WACCM-FV2     piControl    r1i1p1f1
# 33        CMIP               NCAR      CESM2-WACCM     piControl    r1i1p1f1
# 34        CMIP               NCAR            CESM2     piControl    r1i1p1f1
# 35        CMIP                NCC        NorESM1-F     piControl    r1i1p1f1
# 36        CMIP              NUIST            NESM3     piControl    r1i1p1f1
# 37        CMIP                SNU      SAM0-UNICON     piControl    r1i1p1f1
# 38        CMIP                 UA       MCM-UA-1-0     piControl    r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0      Amon         tas         gn
# 1      Amon         tas         gn
# 2      Amon         tas         gn
# 3      Amon         tas         gn
# 4      Amon         tas         gn
# 5      Amon         tas         gn
# 6      Amon         tas         gn
# 7      Amon         tas         gn
# 8      Amon         tas         gn
# 9      Amon         tas         gn
# 10     Amon         tas         gn
# 11     Amon         tas         gn
# 12     Amon         tas         gn
# 13     Amon         tas         gn
# 14     Amon         tas         gn
# 15     Amon         tas         gn
# 16     Amon         tas         gn
# 17     Amon         tas         gn
# 18     Amon         tas         gn
# 19     Amon         tas         gn
# 20     Amon         tas         gn
# 21     Amon         tas         gn
# 22     Amon         tas         gn
# 23     Amon         tas         gn
# 24     Amon         tas         gn
# 25     Amon         tas         gn
# 26     Amon         tas         gn
# 27     Amon         tas         gn
# 28     Amon         tas         gn
# 29     Amon         tas         gn
# 30     Amon         tas         gn
# 31     Amon         tas         gn
# 32     Amon         tas         gn
# 33     Amon         tas         gn
# 34     Amon         tas         gn
# 35     Amon         tas         gn
# 36     Amon         tas         gn
# 37     Amon         tas         gn
# 38     Amon         tas         gn
#
#                                                zstore  dcpp_init_year
# 0   gs://cmip6/CMIP/AS-RCEC/TaiESM1/piControl/r1i1...             NaN
# 1   gs://cmip6/CMIP/BCC/BCC-CSM2-MR/piControl/r1i1...             NaN
# 2   gs://cmip6/CMIP/BCC/BCC-ESM1/piControl/r1i1p1f...             NaN
# 3   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/piControl/r1i...             NaN
# 4   gs://cmip6/CMIP/CAS/FGOALS-g3/piControl/r1i1p1...             NaN
# 5   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p1...             NaN
# 6   gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p2...             NaN
# 7   gs://cmip6/CMIP/CCCR-IITM/IITM-ESM/piControl/r...             NaN
# 8   gs://cmip6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/piCont...             NaN
# 9   gs://cmip6/CMIP/CSIRO/ACCESS-ESM1-5/piControl/...             NaN
# 10  gs://cmip6/CMIP/FIO-QLNM/FIO-ESM-2-0/piControl...             NaN
# 11  gs://cmip6/CMIP/HAMMOZ-Consortium/MPI-ESM-1-2-...             NaN
# 12  gs://cmip6/CMIP/MIROC/MIROC-ES2L/piControl/r1i...             NaN
# 13  gs://cmip6/CMIP/MIROC/MIROC6/piControl/r1i1p1f...             NaN
# 14  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/piControl...             NaN
# 15  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-MM/piControl...             NaN
# 16  gs://cmip6/CMIP/MOHC/UKESM1-0-LL/piControl/r1i...             NaN
# 17  gs://cmip6/CMIP/MPI-M/MPI-ESM1-2-HR/piControl/...             NaN
# 18  gs://cmip6/CMIP/MPI-M/MPI-ESM1-2-LR/piControl/...             NaN
# 19  gs://cmip6/CMIP/MRI/MRI-ESM2-0/piControl/r1i1p...             NaN
# 20  gs://cmip6/CMIP/MRI/MRI-ESM2-0/piControl/r1i2p...             NaN
# 21  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G-CC/piCon...             NaN
# 22  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 23  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 24  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 25  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 26  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 27  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 28  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/piContro...             NaN
# 29  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-H/piContro...             NaN
# 30  gs://cmip6/CMIP/NASA-GISS/GISS-E2-2-G/piContro...             NaN
# 31  gs://cmip6/CMIP/NCAR/CESM2-FV2/piControl/r1i1p...             NaN
# 32  gs://cmip6/CMIP/NCAR/CESM2-WACCM-FV2/piControl...             NaN
# 33  gs://cmip6/CMIP/NCAR/CESM2-WACCM/piControl/r1i...             NaN
# 34  gs://cmip6/CMIP/NCAR/CESM2/piControl/r1i1p1f1/...             NaN
# 35  gs://cmip6/CMIP/NCC/NorESM1-F/piControl/r1i1p1...             NaN
# 36  gs://cmip6/CMIP/NUIST/NESM3/piControl/r1i1p1f1...             NaN
# 37  gs://cmip6/CMIP/SNU/SAM0-UNICON/piControl/r1i1...             NaN
# 38  gs://cmip6/CMIP/UA/MCM-UA-1-0/piControl/r1i1p1...             NaN
